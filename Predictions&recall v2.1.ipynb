# %%
import numpy as np
import pandas as pd
import torch
from allennlp.predictors.predictor import Predictor

# %%
predictor_small = Predictor.from_path("ser_dir_original_model/model.tar.gz")
predictor_large = Predictor.from_path("ser_dir_large_model/model.tar.gz")

# %% [markdown]
# Преобразуем данные из test.csv, парсим по колонкам

# %%
test_df = pd.read_csv('test.csv')[['Event','Xintent','Xemotion','Otheremotion']]
def str2list(x):
    return [y.strip() for y in x[2:-2].replace('"','').replace("'",'').split(',')]
for col in ['Xintent','Xemotion','Otheremotion']:
    test_df[col] = test_df[col].apply(str2list)
    
test_df[1600:1700]
# Out:
#                                           Event  \
# 1600                   PersonX puts paid to ___
# 1601             PersonX fights a losing battle
# 1602             PersonX fights a losing battle
# 1603                       PersonX gathers dust
# 1604               PersonX gets a handle on ___
# 1605               PersonX gets a handle on ___
# 1606                     PersonX stems the tide
# 1607                     PersonX stems the tide
# 1608                     PersonX stems the tide
# 1609                      PersonX sifts out ___
# 1610                      PersonX sifts out ___
# 1611                   PersonX sweetens the pot
# 1612                   PersonX sweetens the pot
# 1613                   PersonX sweetens the pot
# 1614               PersonX fish for compliments
# 1615           PersonX sticks to PersonX's guns
# 1616           PersonX sticks to PersonX's guns
# 1617                 PersonX weathers the storm
# 1618       PersonX gets ___ off PersonX's chest
# 1619       PersonX gets ___ off PersonX's chest
# 1620       PersonX gets ___ off PersonX's chest
# 1621                PersonX gives PersonY grief
# 1622                PersonX gives PersonY grief
# 1623   PersonX has to do with the price of fish
# 1624                         PersonX says grace
# 1625                     PersonX sees the light
# 1626                     PersonX sees the light
# 1627                       PersonX talks turkey
# 1628                       PersonX talks turkey
# 1629                       PersonX talks turkey
# ...                                         ...
# 1670  PersonX bites the hand that feeds PersonX
# 1671  PersonX bites the hand that feeds PersonX
# 1672  PersonX bites the hand that feeds PersonX
# 1673                     PersonX drops the writ
# 1674                     PersonX drops the writ
# 1675                         PersonX beats feet
# 1676             PersonX has PersonX's hand out
# 1677             PersonX has PersonX's hand out
# 1678                        PersonX rings false
# 1679                         PersonX cant helps
# 1680                         PersonX cant helps
# 1681                     PersonX raises the bar
# 1682                            PersonX eats it
# 1683                            PersonX eats it
# 1684                    PersonX drops the topic
# 1685                    PersonX drops the topic
# 1686                        PersonX takes a nap
# 1687                        PersonX takes a nap
# 1688                        PersonX takes a nap
# 1689            PersonX fights PersonX's corner
# 1690                     PersonX works the room
# 1691                     PersonX works the room
# 1692        PersonX plays PersonX's cards right
# 1693        PersonX plays PersonX's cards right
# 1694                     PersonX puts in motion
# 1695            PersonX cleans up PersonX's act
# 1696            PersonX cleans up PersonX's act
# 1697             PersonX takes ___ to the grave
# 1698             PersonX takes ___ to the grave
# 1699          PersonX outpope the pope the pope
#
#                                                 Xintent  \
# 1600                         [to finalize, to complete]
# 1601                                             [none]
# 1602                           [doesnt want to give up]
# 1603                                             [none]
# 1604                   [to learn more about a subject.]
# 1605                                             [none]
# 1606                       [stop things from happening]
# 1607                           [slow or stop something]
# 1608        [to shut down something, to stop questions]
# 1609                                 [separate things.]
# 1610               [to separate out something valuable]
# 1611                       [to make things interesting]
# 1612     [to create more interest, to raise the stakes]
# 1613                               [the goal to be met]
# 1614  [reassurance from his friends and family, to k...
# 1615                          [to be sure of themself.]
# 1616                                         [to learn]
# 1617                                             [none]
# 1618           [to reveal something, to share a secret]
# 1619                                       [to tell it]
# 1620  [to clear the air, to share concerns, to be ho...
# 1621                            [to a pain in the neck]
# 1622                                             [none]
# 1623                                             [none]
# 1624                                          [to pray]
# 1625                        [to understand the problem]
# 1626                                             [none]
# 1627                                     [to negotiate]
# 1628         [to be honest, to be frank, to be sincere]
# 1629                      [to talk in a serious manner]
# ...                                                 ...
# 1670          [to sabotage the help they are receiving]
# 1671   [the other person to feel threatened, more food]
# 1672                                          [to bite]
# 1673                                          [closure]
# 1674                           [to dissolve parliament]
# 1675                                             [none]
# 1676                                      [money, help]
# 1677                               [relief, assistance]
# 1678                                             [none]
# 1679                                             [none]
# 1680                                             [none]
# 1681                       [to create better standards]
# 1682                      [energy, to taste new things]
# 1683                                             [none]
# 1684                           [to change the subject.]
# 1685           [to no longer discuss the topic at hand]
# 1686       [to not be tired, to take a break, to sleep]
# 1687                              [to sleep., is tired]
# 1688            [to rest., to help a headache go away.]
# 1689  [personx believes they are correct, wants to c...
# 1690  [socialize and network with others, possibly f...
# 1691  [to make connections, to gain friends, to gain...
# 1692                                 [to be successful]
# 1693                                [to be successful.]
# 1694                             [to start things out.]
# 1695    [to improve themselvves, to be a better person]
# 1696                            [to make a better life]
# 1697                          [satisfied with themself]
# 1698                                 [to keep a secret]
# 1699  [act as a more authentic member of a group tha...
#
#                                                Xemotion  \
# 1600                                 [final, completed]
# 1601                         [discouraged, beaten, sad]
# 1602                             [proud and persistant]
# 1603   [bad for not having anything constructive to do]
# 1604                                        [informed.]
# 1605                                        [satisfied]
# 1606                                           [heroic]
# 1607                                              [nan]
# 1608                                         [relieved]
# 1609                                       [satisfied.]
# 1610                      [expectant to find something]
# 1611                                      [competitive]
# 1612                                            [eager]
# 1613                                          [hopeful]
# 1614                    [reassured, confident, content]
# 1615                                       [in charge.]
# 1616                                            [happy]
# 1617                                           [strong]
# 1618                                         [relieved]
# 1619                                         [relieved]
# 1620                     [relieved, fearful of outcome]
# 1621                                              [bad]
# 1622                                       [sad, sorry]
# 1623                            [powerful, influential]
# 1624                                         [thankful]
# 1625                         [relieved, happy, smarter]
# 1626                          [blinded, elated, scared]
# 1627                      [like they made a great deal]
# 1628                       [honest, loyal, trustworthy]
# 1629  [satisfied because they were able to tell some...
# ...                                                 ...
# 1670                                          [ashamed]
# 1671                                       [in control]
# 1672                                              [bad]
# 1673                                         [defeated]
# 1674                           [like a powerful person]
# 1675                                            [bored]
# 1676                         [helpless, abused, helped]
# 1677                             [embarrassed, hopeful]
# 1678                                [sad, down hearted]
# 1679                         [useless, inept, disabled]
# 1680                             [unhappy, sympathetic]
# 1681                            [accomplished, dutiful]
# 1682                                      [happy, full]
# 1683                                 [embarassed, hurt]
# 1684                                 [not good enough.]
# 1685          [relieved to be done with the discussion]
# 1686                            [relaxed, awake, alert]
# 1687                             [refreshed, energized]
# 1688                   [refreshed, energetic, cheerful]
# 1689  [satisfied, correct, like they have won respec...
# 1690                                            [proud]
# 1691                           [accomplished, friendly]
# 1692                                [successful, happy]
# 1693                                           [happy.]
# 1694                                 [good for leading]
# 1695    [improved, better about themselves as a person]
# 1696                 [satisfaction, relief, triumphant]
# 1697                                        [satisfied]
# 1698                                        [secretive]
# 1699                                 [snobbish, expert]
#
#                                            Otheremotion
# 1600                                             [none]
# 1601                                      [sympathetic]
# 1602                                             [none]
# 1603                                             [none]
# 1604                                             [none]
# 1605                                             [none]
# 1606                                             [safe]
# 1607                                             [none]
# 1608                                       [frustrated]
# 1609                                             [none]
# 1610                                             [none]
# 1611                            [excited, anticipating]
# 1612                                             [none]
# 1613                    [hopeful, compelled to do well]
# 1614                                             [none]
# 1615                                             [none]
# 1616                                             [none]
# 1617                                             [none]
# 1618                           [surprised, trustworthy]
# 1619                                             [none]
# 1620      [trusted, upset they werent informed earlier]
# 1621                                            [upset]
# 1622                                      [hurt, grief]
# 1623                     [bled dry, financially pained]
# 1624                                             [none]
# 1625                                             [none]
# 1626                                             [none]
# 1627                            [like they made a deal]
# 1628                   [relieved, honored, trustworthy]
# 1629  [like they have to do something about this new...
# ...                                                 ...
# 1670                                         [betrayed]
# 1671                                  [sad, mad, angry]
# 1672                                             [hurt]
# 1673                                         [relieved]
# 1674                                        [surprised]
# 1675                                             [none]
# 1676                        [guilty, heartless, stingy]
# 1677                                  [awkward, uneasy]
# 1678                                             [none]
# 1679                            [unsupported, betrayed]
# 1680                                [disappointed, sad]
# 1681                                             [none]
# 1682                                             [none]
# 1683                                             [none]
# 1684                                             [none]
# 1685      [relieved to be done talking about the topic]
# 1686                                             [none]
# 1687                                             [none]
# 1688                                             [none]
# 1689                                             [none]
# 1690                      [like they have been noticed]
# 1691                                 [popular, engaged]
# 1692                                            [happy]
# 1693                                             [none]
# 1694  [good for having followed., jealousy if they t...
# 1695                                             [none]
# 1696                                            [happy]
# 1697                                             [none]
# 1698                                             [none]
# 1699                               [annoyed, impressed]
#
# [100 rows x 4 columns]

# %% [markdown]
# Группируем по фразам отдельно намерения, эмоции субъекта и эмоции окружающих

# %%
phrase2oemotion = {}
phrase2xemotion = {}
phrase2xintent = {}
res_xi = []
res_xe = []
res_oe = []

phrase_set = set([x for x in test_df.Event])

for phrase in phrase_set:
    for x in test_df[test_df.Event == phrase].Xintent:
        res_xi += x
    phrase2xintent[phrase] = set(res_xi)
    res_xi.clear()
    for x in test_df[test_df.Event == phrase].Xemotion:
        res_xe += x
    phrase2xemotion[phrase] = set(res_xe)
    res_xe.clear()
    for x in test_df[test_df.Event == phrase].Otheremotion:
        res_oe += x
    phrase2oemotion[phrase] = set(res_oe)
    res_oe.clear()

# %%
p = "PersonX takes a nap"

# %%
phrase2xintent[p]
# Out:
# {'is tired',
#  'to help a headache go away.',
#  'to not be tired',
#  'to rest.',
#  'to sleep',
#  'to sleep.',
#  'to take a break'}

# %%
result = predictor_large.predict(source=p)

oreact = set([" ".join(react) for react in result["oreact_top_k_predicted_tokens"]])    
intents = set([" ".join(react) for react in result["xintent_top_k_predicted_tokens"]])
xreact = set([" ".join(react) for react in result["xreact_top_k_predicted_tokens"]])

intents
# Out:
# {'get rest',
#  'get some rest',
#  'get to work',
#  'have fun',
#  'relax',
#  'rest',
#  'rest .',
#  'rested',
#  'sleep',
#  'take rest'}

# %% [markdown]
# Считаем recall следующим образом: из всех вариантов, выданных моделью для данной фразы, оставляем те, что есть в контрольном множестве фразы, сформированном ранее, и делим их количество на размер контрольного множества. Затем делим полученную сумму на количество фраз. Проделываем для каждого из выходов (intent, xreact и oreact)

# %%
res_oe = 0
res_xe = 0
res_xi = 0

for phrase in phrase_set:
    result = predictor_small.predict(source=phrase)

    oreact = set([" ".join(react) for react in result["oreact_top_k_predicted_tokens"]])    
    intents = set([" ".join(react) for react in result["xintent_top_k_predicted_tokens"]])
    xreact = set([" ".join(react) for react in result["xreact_top_k_predicted_tokens"]])

    res_oe += len(phrase2oemotion[phrase].intersection(oreact)) / len(phrase2oemotion[phrase])
    res_xe += len(phrase2xemotion[phrase].intersection(xreact)) / len(phrase2xemotion[phrase])
    res_xi += len(phrase2xintent[phrase].intersection(intents)) / len(phrase2xintent[phrase])

print("Recall for intents: ", res_xi / len(phrase_set))
print("Recall for x_react: ", res_xe / len(phrase_set))
print("Recall for o_react: ", res_oe / len(phrase_set))
# Out:
# Recall for intents:  0.20332426906132062
# Recall for x_react:  0.23903328485001757
# Recall for o_react:  0.6408387613566894

# %%
res_oe = 0
res_xe = 0
res_xi = 0

for phrase in phrase_set:
    result = predictor_large.predict(source=phrase)

    oreact = set([" ".join(react) for react in result["oreact_top_k_predicted_tokens"]])    
    intents = set([" ".join(react) for react in result["xintent_top_k_predicted_tokens"]])
    xreact = set([" ".join(react) for react in result["xreact_top_k_predicted_tokens"]])

    res_oe += len(phrase2oemotion[phrase].intersection(oreact)) / len(phrase2oemotion[phrase])
    res_xe += len(phrase2xemotion[phrase].intersection(xreact)) / len(phrase2xemotion[phrase])
    res_xi += len(phrase2xintent[phrase].intersection(intents)) / len(phrase2xintent[phrase])

print("Recall for intents: ", res_xi / len(phrase_set))
print("Recall for x_react: ", res_xe / len(phrase_set))
print("Recall for o_react: ", res_oe / len(phrase_set))

# %%
res_oe = 0
res_xe = 0
res_xi = 0
count = 0

for phrase in phrase_set:
    result = predictor_large.predict(source=phrase)

    oreact = set([" ".join(react) for react in result["oreact_top_k_predicted_tokens"]])    
    intents = set([" ".join(react) for react in result["xintent_top_k_predicted_tokens"]])
    xreact = set([" ".join(react) for react in result["xreact_top_k_predicted_tokens"]])

    res_oe += len(phrase2oemotion[phrase].intersection(oreact)) / len(phrase2oemotion[phrase]) * test_df[test_df.Event == phrase].shape[0]
    res_xe += len(phrase2xemotion[phrase].intersection(xreact)) / len(phrase2xemotion[phrase]) * test_df[test_df.Event == phrase].shape[0]
    res_xi += len(phrase2xintent[phrase].intersection(intents)) / len(phrase2xintent[phrase]) * test_df[test_df.Event == phrase].shape[0]
    
    count += test_df[test_df.Event == phrase].shape[0]

print("Recall for intents: ", res_xi / count)
print("Recall for x_react: ", res_xe / count)
print("Recall for o_react: ", res_oe / count)
